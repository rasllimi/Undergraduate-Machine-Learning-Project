# %% [markdown]
# ### Import the required libraries

# %%
import odbind as odb
from odbind.survey import Survey
from odbind.well import Well
import pandas as pd
import numpy as np

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ### Load the survey from Opendtect

# %%
sdata = Survey("UnderGrad_Proj")

# %% [markdown]
# ### Well Data

# %%
wells = Well.names(sdata)

# %%
wells
# Out:
# ['EBONI-01ST',
#  'EBONI-02',
#  'EBONI-03ST',
#  'EBONI-04',
#  'EBONI-04G',
#  'EBONI-05G',
#  'EBONI-05ST',
#  'EBONI-06',
#  'EBONI-07T1',
#  'EBONI-10',
#  'EBONI-13T1',
#  'EBONI-14',
#  'EBONI-14G1',
#  'EBONI-14T2']

# %% [markdown]
# #### Well Logs informations

# %%
well1 = Well(sdata,wells[0])


well1.log_info_dataframe()
# Out:
#                                 name mnemonic    uom  \
# 0                         AVO_Vp_1_1               m
# 1                       AVO_Vp_100_1               m
# 2                         AVO_VpVs_1               m
# 3                     AVO_VpVs_100_1               m
# 4                             DTCV_1       DT  us/ft
# 5                             DTCV_2       DT  us/ft
# 6                     ELASTIC_RHOB_1     RHOB   g/cc
# 7                             HCAL_1      CAL     in
# 8                             HCAL_2      CAL     in
# 9            PEM2010_INPUT_DTC_ISO_1       DT  us/ft
# 10                PEM2010_INPUT_NP_1
# 11              PEM2010_INPUT_RHOB_1     RHOB   g/cc
# 12                PEM2010_INPUT_RT_1       RT   ohmm
# 13               PEM2010_INPUT_SWE_1       SW
# 14               PEM2010_INPUT_SWT_1      SWT
# 15               PEM2010_INPUT_VCL_1      VCL
# 16                     petro_LNDTP_1       DT  us/ft
# 17                    PETROLAN_SWE_1       SW
# 18  PETROLAN_SWE_BupperFullofWater_1       RT
# 19                    PETROLAN_SWT_1      SWT
# 20                    PETROLAN_VCL_1      VCL
# 21                          RHOB_1_1               m
# 22                            RHOZ_1     RHOB   g/cc
# 23                            RHOZ_2     RHOB   g/cc
# 24                            TNPH_1
# 25                            TNPH_2
# 26                         TNPHCOR_1
# 27                         TNPHCOR_2
# 28                            VP_1_1               m
# 29                          VP_100_1               m
# 30                            VpVs_1               m
# 31                        VpVs_100_1               m
# 32                            VS_1_1               m
# 33                        VS_1_100_1               m
#
#                                  dah_range  \
# 0       [2790.2783203125, 4171.0224609375]
# 1     [1401.761962890625, 4171.4794921875]
# 2       [2790.2783203125, 4171.0224609375]
# 3       [2790.2783203125, 4171.4794921875]
# 4   [1990.4964599609375, 4171.49267578125]
# 5   [1990.4964599609375, 4171.49267578125]
# 6     [2790.29150390625, 4179.56982421875]
# 7     [2699.91845703125, 4173.62646484375]
# 8     [2699.91845703125, 4173.62646484375]
# 9     [2790.13916015625, 4170.88330078125]
# 10     [2790.13916015625, 4171.9501953125]
# 11    [2790.29150390625, 4179.56982421875]
# 12     [1406.19482421875, 4125.4677734375]
# 13    [2790.13916015625, 4179.56982421875]
# 14    [2790.13916015625, 4179.56982421875]
# 15    [2790.13916015625, 4179.56982421875]
# 16   [1990.483154296875, 4171.18798828125]
# 17            [2790.13916015625, 4179.875]
# 18            [2790.13916015625, 4179.875]
# 19            [2790.13916015625, 4179.875]
# 20            [2790.13916015625, 4179.875]
# 21       [2790.4306640625, 4179.708984375]
# 22    [2699.91845703125, 4176.82666015625]
# 23    [2699.91845703125, 4176.82666015625]
# 24      [2700.3623046875, 4172.4072265625]
# 25      [2700.3623046875, 4172.4072265625]
# 26      [2700.3623046875, 4172.4072265625]
# 27      [2700.3623046875, 4172.4072265625]
# 28      [2790.2783203125, 4171.0224609375]
# 29    [1401.761962890625, 4171.4794921875]
# 30      [2790.2783203125, 4171.0224609375]
# 31      [2790.2783203125, 4171.4794921875]
# 32      [2790.2783203125, 4171.0224609375]
# 33      [2790.2783203125, 4171.0224609375]
#
#                                   log_range
# 0      [2137.380615234375, 4558.8427734375]
# 1     [2137.380615234375, 4540.20654296875]
# 2                          [1.4392, 3.1212]
# 3                          [1.4895, 3.1212]
# 4    [66.90570068359375, 173.4116973876953]
# 5    [66.90570068359375, 173.4116973876953]
# 6    [1.973520040512085, 2.605590105056763]
# 7              [5.6468, 24.669599533081055]
# 8              [5.6468, 24.669599533081055]
# 9   [66.80235290527344, 142.81463623046875]
# 10              [0.0661, 1.117159962654114]
# 11   [1.973520040512085, 2.605590105056763]
# 12            [0.13436, 51.647708892822266]
# 13                     [0.0002800000075, 1]
# 14                              [0.0143, 1]
# 15                                   [0, 1]
# 16  [66.84628295898438, 173.40733337402344]
# 17                              [0.0001, 1]
# 18                   [0.986670017242432, 1]
# 19                              [0.0143, 1]
# 20                                   [0, 1]
# 21                         [1.9761, 2.5986]
# 22                         [1.5558, 2.6724]
# 23                         [1.5558, 2.6724]
# 24              [0.0661, 1.530679941177368]
# 25              [0.0661, 1.530679941177368]
# 26              [0.0661, 1.530679941177368]
# 27              [0.0661, 1.530679941177368]
# 28     [2137.380615234375, 4558.8427734375]
# 29    [2137.380615234375, 4540.20654296875]
# 30                         [1.4392, 3.1212]
# 31                         [1.4895, 3.1212]
# 32   [740.3840942382812, 2571.191650390625]
# 33   [740.3840942382812, 2571.191650390625]

# %%
well1.track_dataframe()
# Out:
#            dah        tvdss         x         y
# 0     0.000000     0.000000  586583.6  343852.9
# 1  4188.256836  4188.256836  586583.6  343852.9

# %% [markdown]
# #### Load all the well logs into a panda dataframe

# %%
well_list = []

for well in wells:
    EB= Well(sdata, well)
    df = EB.logs_dataframe()[0]
    df['WELL'] = well
    well_list.append(df)

# %%
well_df = pd.concat(well_list)

# %%
well_df.T
# Out:
#                                          0            1            2     \
# dah                                    1401.5       1402.0       1402.5
# AVO_Vp_1_1                                NaN          NaN          NaN
# AVO_Vp_100_1                      2241.375732  2241.375732  2241.375732
# AVO_VpVs_1                                NaN          NaN          NaN
# AVO_VpVs_100_1                            NaN          NaN          NaN
# DTCV_1                                    NaN          NaN          NaN
# DTCV_2                                    NaN          NaN          NaN
# ELASTIC_RHOB_1                            NaN          NaN          NaN
# HCAL_1                                    NaN          NaN          NaN
# HCAL_2                                    NaN          NaN          NaN
# PEM2010_INPUT_DTC_ISO_1                   NaN          NaN          NaN
# PEM2010_INPUT_NP_1                        NaN          NaN          NaN
# PEM2010_INPUT_RHOB_1                      NaN          NaN          NaN
# PEM2010_INPUT_RT_1                        NaN          NaN          NaN
# PEM2010_INPUT_SWE_1                       NaN          NaN          NaN
# PEM2010_INPUT_SWT_1                       NaN          NaN          NaN
# PEM2010_INPUT_VCL_1                       NaN          NaN          NaN
# petro_LNDTP_1                             NaN          NaN          NaN
# PETROLAN_SWE_1                            NaN          NaN          NaN
# PETROLAN_SWE_BupperFullofWater_1          NaN          NaN          NaN
# PETROLAN_SWT_1                            NaN          NaN          NaN
# PETROLAN_VCL_1                            NaN          NaN          NaN
# RHOB_1_1                                  NaN          NaN          NaN
# RHOZ_1                                    NaN          NaN          NaN
# RHOZ_2                                    NaN          NaN          NaN
# TNPH_1                                    NaN          NaN          NaN
# TNPH_2                                    NaN          NaN          NaN
# TNPHCOR_1                                 NaN          NaN          NaN
# TNPHCOR_2                                 NaN          NaN          NaN
# VP_1_1                                    NaN          NaN          NaN
# VP_100_1                          2241.375732  2241.375732  2241.375732
# VpVs_1                                    NaN          NaN          NaN
# VpVs_100_1                                NaN          NaN          NaN
# VS_1_1                                    NaN          NaN          NaN
# VS_1_100_1                                NaN          NaN          NaN
# WELL                               EBONI-01ST   EBONI-01ST   EBONI-01ST
# AVO_VpVs_1_1                              NaN          NaN          NaN
# CALI_COMP_1                               NaN          NaN          NaN
# DTP_COMP_1                                NaN          NaN          NaN
# ELASTIC_DTC_1                             NaN          NaN          NaN
# NP_COMP_1                                 NaN          NaN          NaN
# PEM2010_INPUT_DTC_1                       NaN          NaN          NaN
# RHOB_COMP_1                               NaN          NaN          NaN
# RT_COMP_1                                 NaN          NaN          NaN
# PETROLAN_SWE_2                            NaN          NaN          NaN
# PETROLAN_SWT_2                            NaN          NaN          NaN
# CALI_COMP_2                               NaN          NaN          NaN
# NP_COMP_2                                 NaN          NaN          NaN
# RHOB_COMP_2                               NaN          NaN          NaN
# RT_COMP_2                                 NaN          NaN          NaN
# PEM2010_INPUT_RT_int_1                    NaN          NaN          NaN
# PETROLAN_VCL_2                            NaN          NaN          NaN
#
#                                          3            4            5     \
# dah                                    1403.0       1403.5       1404.0
# AVO_Vp_1_1                                NaN          NaN          NaN
# AVO_Vp_100_1                      2241.375732  2241.375732  2241.375732
# AVO_VpVs_1                                NaN          NaN          NaN
# AVO_VpVs_100_1                            NaN          NaN          NaN
# DTCV_1                                    NaN          NaN          NaN
# DTCV_2                                    NaN          NaN          NaN
# ELASTIC_RHOB_1                            NaN          NaN          NaN
# HCAL_1                                    NaN          NaN          NaN
# HCAL_2                                    NaN          NaN          NaN
# PEM2010_INPUT_DTC_ISO_1                   NaN          NaN          NaN
# PEM2010_INPUT_NP_1                        NaN          NaN          NaN
# PEM2010_INPUT_RHOB_1                      NaN          NaN          NaN
# PEM2010_INPUT_RT_1                        NaN          NaN          NaN
# PEM2010_INPUT_SWE_1                       NaN          NaN          NaN
# PEM2010_INPUT_SWT_1                       NaN          NaN          NaN
# PEM2010_INPUT_VCL_1                       NaN          NaN          NaN
# petro_LNDTP_1                             NaN          NaN          NaN
# PETROLAN_SWE_1                            NaN          NaN          NaN
# PETROLAN_SWE_BupperFullofWater_1          NaN          NaN          NaN
# PETROLAN_SWT_1                            NaN          NaN          NaN
# PETROLAN_VCL_1                            NaN          NaN          NaN
# RHOB_1_1                                  NaN          NaN          NaN
# RHOZ_1                                    NaN          NaN          NaN
# RHOZ_2                                    NaN          NaN          NaN
# TNPH_1                                    NaN          NaN          NaN
# TNPH_2                                    NaN          NaN          NaN
# TNPHCOR_1                                 NaN          NaN          NaN
# TNPHCOR_2                                 NaN          NaN          NaN
# VP_1_1                                    NaN          NaN          NaN
# VP_100_1                          2241.375732  2241.375732  2241.375732
# VpVs_1                                    NaN          NaN          NaN
# VpVs_100_1                                NaN          NaN          NaN
# VS_1_1                                    NaN          NaN          NaN
# VS_1_100_1                                NaN          NaN          NaN
# WELL                               EBONI-01ST   EBONI-01ST   EBONI-01ST
# AVO_VpVs_1_1                              NaN          NaN          NaN
# CALI_COMP_1                               NaN          NaN          NaN
# DTP_COMP_1                                NaN          NaN          NaN
# ELASTIC_DTC_1                             NaN          NaN          NaN
# NP_COMP_1                                 NaN          NaN          NaN
# PEM2010_INPUT_DTC_1                       NaN          NaN          NaN
# RHOB_COMP_1                               NaN          NaN          NaN
# RT_COMP_1                                 NaN          NaN          NaN
# PETROLAN_SWE_2                            NaN          NaN          NaN
# PETROLAN_SWT_2                            NaN          NaN          NaN
# CALI_COMP_2                               NaN          NaN          NaN
# NP_COMP_2                                 NaN          NaN          NaN
# RHOB_COMP_2                               NaN          NaN          NaN
# RT_COMP_2                                 NaN          NaN          NaN
# PEM2010_INPUT_RT_int_1                    NaN          NaN          NaN
# PETROLAN_VCL_2                            NaN          NaN          NaN
#
#                                          6            7            8     \
# dah                                    1404.5       1405.0       1405.5
# AVO_Vp_1_1                                NaN          NaN          NaN
# AVO_Vp_100_1                      2241.375732  2241.375732  2241.375732
# AVO_VpVs_1                                NaN          NaN          NaN
# AVO_VpVs_100_1                            NaN          NaN          NaN
# DTCV_1                                    NaN          NaN          NaN
# DTCV_2                                    NaN          NaN          NaN
# ELASTIC_RHOB_1                            NaN          NaN          NaN
# HCAL_1                                    NaN          NaN          NaN
# HCAL_2                                    NaN          NaN          NaN
# PEM2010_INPUT_DTC_ISO_1                   NaN          NaN          NaN
# PEM2010_INPUT_NP_1                        NaN          NaN          NaN
# PEM2010_INPUT_RHOB_1                      NaN          NaN          NaN
# PEM2010_INPUT_RT_1                        NaN          NaN          NaN
# PEM2010_INPUT_SWE_1                       NaN          NaN          NaN
# PEM2010_INPUT_SWT_1                       NaN          NaN          NaN
# PEM2010_INPUT_VCL_1                       NaN          NaN          NaN
# petro_LNDTP_1                             NaN          NaN          NaN
# PETROLAN_SWE_1                            NaN          NaN          NaN
# PETROLAN_SWE_BupperFullofWater_1          NaN          NaN          NaN
# PETROLAN_SWT_1                            NaN          NaN          NaN
# PETROLAN_VCL_1                            NaN          NaN          NaN
# RHOB_1_1                                  NaN          NaN          NaN
# RHOZ_1                                    NaN          NaN          NaN
# RHOZ_2                                    NaN          NaN          NaN
# TNPH_1                                    NaN          NaN          NaN
# TNPH_2                                    NaN          NaN          NaN
# TNPHCOR_1                                 NaN          NaN          NaN
# TNPHCOR_2                                 NaN          NaN          NaN
# VP_1_1                                    NaN          NaN          NaN
# VP_100_1                          2241.375732  2241.375732  2241.375732
# VpVs_1                                    NaN          NaN          NaN
# VpVs_100_1                                NaN          NaN          NaN
# VS_1_1                                    NaN          NaN          NaN
# VS_1_100_1                                NaN          NaN          NaN
# WELL                               EBONI-01ST   EBONI-01ST   EBONI-01ST
# AVO_VpVs_1_1                              NaN          NaN          NaN
# CALI_COMP_1                               NaN          NaN          NaN
# DTP_COMP_1                                NaN          NaN          NaN
# ELASTIC_DTC_1                             NaN          NaN          NaN
# NP_COMP_1                                 NaN          NaN          NaN
# PEM2010_INPUT_DTC_1                       NaN          NaN          NaN
# RHOB_COMP_1                               NaN          NaN          NaN
# RT_COMP_1                                 NaN          NaN          NaN
# PETROLAN_SWE_2                            NaN          NaN          NaN
# PETROLAN_SWT_2                            NaN          NaN          NaN
# CALI_COMP_2                               NaN          NaN          NaN
# NP_COMP_2                                 NaN          NaN          NaN
# RHOB_COMP_2                               NaN          NaN          NaN
# RT_COMP_2                                 NaN          NaN          NaN
# PEM2010_INPUT_RT_int_1                    NaN          NaN          NaN
# PETROLAN_VCL_2                            NaN          NaN          NaN
#
#                                          9     ...        6947        6948  \
# dah                                    1406.0  ...      5492.5      5493.0
# AVO_Vp_1_1                                NaN  ...         NaN         NaN
# AVO_Vp_100_1                      2241.375488  ...         NaN         NaN
# AVO_VpVs_1                                NaN  ...         NaN         NaN
# AVO_VpVs_100_1                            NaN  ...         NaN         NaN
# DTCV_1                                    NaN  ...         NaN         NaN
# DTCV_2                                    NaN  ...         NaN         NaN
# ELASTIC_RHOB_1                            NaN  ...         NaN         NaN
# HCAL_1                                    NaN  ...         NaN         NaN
# HCAL_2                                    NaN  ...         NaN         NaN
# PEM2010_INPUT_DTC_ISO_1                   NaN  ...         NaN         NaN
# PEM2010_INPUT_NP_1                        NaN  ...         NaN         NaN
# PEM2010_INPUT_RHOB_1                      NaN  ...         NaN         NaN
# PEM2010_INPUT_RT_1                       0.52  ...         NaN         NaN
# PEM2010_INPUT_SWE_1                       NaN  ...         NaN         NaN
# PEM2010_INPUT_SWT_1                       NaN  ...         NaN         NaN
# PEM2010_INPUT_VCL_1                       NaN  ...         NaN         NaN
# petro_LNDTP_1                             NaN  ...         NaN         NaN
# PETROLAN_SWE_1                            NaN  ...         NaN         NaN
# PETROLAN_SWE_BupperFullofWater_1          NaN  ...         NaN         NaN
# PETROLAN_SWT_1                            NaN  ...         NaN         NaN
# PETROLAN_VCL_1                            NaN  ...         NaN         NaN
# RHOB_1_1                                  NaN  ...         NaN         NaN
# RHOZ_1                                    NaN  ...         NaN         NaN
# RHOZ_2                                    NaN  ...         NaN         NaN
# TNPH_1                                    NaN  ...         NaN         NaN
# TNPH_2                                    NaN  ...         NaN         NaN
# TNPHCOR_1                                 NaN  ...         NaN         NaN
# TNPHCOR_2                                 NaN  ...         NaN         NaN
# VP_1_1                                    NaN  ...         NaN         NaN
# VP_100_1                          2241.375488  ...         NaN         NaN
# VpVs_1                                    NaN  ...         NaN         NaN
# VpVs_100_1                                NaN  ...         NaN         NaN
# VS_1_1                                    NaN  ...         NaN         NaN
# VS_1_100_1                                NaN  ...         NaN         NaN
# WELL                               EBONI-01ST  ...  EBONI-14T2  EBONI-14T2
# AVO_VpVs_1_1                              NaN  ...         NaN         NaN
# CALI_COMP_1                               NaN  ...         NaN         NaN
# DTP_COMP_1                                NaN  ...         NaN         NaN
# ELASTIC_DTC_1                             NaN  ...         NaN         NaN
# NP_COMP_1                                 NaN  ...         NaN         NaN
# PEM2010_INPUT_DTC_1                       NaN  ...         NaN         NaN
# RHOB_COMP_1                               NaN  ...         NaN         NaN
# RT_COMP_1                                 NaN  ...  403.715515    402.2771
# PETROLAN_SWE_2                            NaN  ...         NaN         NaN
# PETROLAN_SWT_2                            NaN  ...         NaN         NaN
# CALI_COMP_2                               NaN  ...         NaN         NaN
# NP_COMP_2                                 NaN  ...         NaN         NaN
# RHOB_COMP_2                               NaN  ...         NaN         NaN
# RT_COMP_2                                 NaN  ...         NaN         NaN
# PEM2010_INPUT_RT_int_1                    NaN  ...         NaN         NaN
# PETROLAN_VCL_2                            NaN  ...         NaN         NaN
#
#                                         6949        6950        6951  \
# dah                                   5493.5      5494.0      5494.5
# AVO_Vp_1_1                               NaN         NaN         NaN
# AVO_Vp_100_1                             NaN         NaN         NaN
# AVO_VpVs_1                               NaN         NaN         NaN
# AVO_VpVs_100_1                           NaN         NaN         NaN
# DTCV_1                                   NaN         NaN         NaN
# DTCV_2                                   NaN         NaN         NaN
# ELASTIC_RHOB_1                           NaN         NaN         NaN
# HCAL_1                                   NaN         NaN         NaN
# HCAL_2                                   NaN         NaN         NaN
# PEM2010_INPUT_DTC_ISO_1                  NaN         NaN         NaN
# PEM2010_INPUT_NP_1                       NaN         NaN         NaN
# PEM2010_INPUT_RHOB_1                     NaN         NaN         NaN
# PEM2010_INPUT_RT_1                       NaN         NaN         NaN
# PEM2010_INPUT_SWE_1                      NaN         NaN         NaN
# PEM2010_INPUT_SWT_1                      NaN         NaN         NaN
# PEM2010_INPUT_VCL_1                      NaN         NaN         NaN
# petro_LNDTP_1                            NaN         NaN         NaN
# PETROLAN_SWE_1                           NaN         NaN         NaN
# PETROLAN_SWE_BupperFullofWater_1         NaN         NaN         NaN
# PETROLAN_SWT_1                           NaN         NaN         NaN
# PETROLAN_VCL_1                           NaN         NaN         NaN
# RHOB_1_1                                 NaN         NaN         NaN
# RHOZ_1                                   NaN         NaN         NaN
# RHOZ_2                                   NaN         NaN         NaN
# TNPH_1                                   NaN         NaN         NaN
# TNPH_2                                   NaN         NaN         NaN
# TNPHCOR_1                                NaN         NaN         NaN
# TNPHCOR_2                                NaN         NaN         NaN
# VP_1_1                                   NaN         NaN         NaN
# VP_100_1                                 NaN         NaN         NaN
# VpVs_1                                   NaN         NaN         NaN
# VpVs_100_1                               NaN         NaN         NaN
# VS_1_1                                   NaN         NaN         NaN
# VS_1_100_1                               NaN         NaN         NaN
# WELL                              EBONI-14T2  EBONI-14T2  EBONI-14T2
# AVO_VpVs_1_1                             NaN         NaN         NaN
# CALI_COMP_1                              NaN         NaN         NaN
# DTP_COMP_1                               NaN         NaN         NaN
# ELASTIC_DTC_1                            NaN         NaN         NaN
# NP_COMP_1                                NaN         NaN         NaN
# PEM2010_INPUT_DTC_1                      NaN         NaN         NaN
# RHOB_COMP_1                              NaN         NaN         NaN
# RT_COMP_1                         404.211151  413.434387  411.969086
# PETROLAN_SWE_2                           NaN         NaN         NaN
# PETROLAN_SWT_2                           NaN         NaN         NaN
# CALI_COMP_2                              NaN         NaN         NaN
# NP_COMP_2                                NaN         NaN         NaN
# RHOB_COMP_2                              NaN         NaN         NaN
# RT_COMP_2                                NaN         NaN         NaN
# PEM2010_INPUT_RT_int_1                   NaN         NaN         NaN
# PETROLAN_VCL_2                           NaN         NaN         NaN
#
#                                         6952        6953        6954  \
# dah                                   5495.0      5495.5      5496.0
# AVO_Vp_1_1                               NaN         NaN         NaN
# AVO_Vp_100_1                             NaN         NaN         NaN
# AVO_VpVs_1                               NaN         NaN         NaN
# AVO_VpVs_100_1                           NaN         NaN         NaN
# DTCV_1                                   NaN         NaN         NaN
# DTCV_2                                   NaN         NaN         NaN
# ELASTIC_RHOB_1                           NaN         NaN         NaN
# HCAL_1                                   NaN         NaN         NaN
# HCAL_2                                   NaN         NaN         NaN
# PEM2010_INPUT_DTC_ISO_1                  NaN         NaN         NaN
# PEM2010_INPUT_NP_1                       NaN         NaN         NaN
# PEM2010_INPUT_RHOB_1                     NaN         NaN         NaN
# PEM2010_INPUT_RT_1                       NaN         NaN         NaN
# PEM2010_INPUT_SWE_1                      NaN         NaN         NaN
# PEM2010_INPUT_SWT_1                      NaN         NaN         NaN
# PEM2010_INPUT_VCL_1                      NaN         NaN         NaN
# petro_LNDTP_1                            NaN         NaN         NaN
# PETROLAN_SWE_1                           NaN         NaN         NaN
# PETROLAN_SWE_BupperFullofWater_1         NaN         NaN         NaN
# PETROLAN_SWT_1                           NaN         NaN         NaN
# PETROLAN_VCL_1                           NaN         NaN         NaN
# RHOB_1_1                                 NaN         NaN         NaN
# RHOZ_1                                   NaN         NaN         NaN
# RHOZ_2                                   NaN         NaN         NaN
# TNPH_1                                   NaN         NaN         NaN
# TNPH_2                                   NaN         NaN         NaN
# TNPHCOR_1                                NaN         NaN         NaN
# TNPHCOR_2                                NaN         NaN         NaN
# VP_1_1                                   NaN         NaN         NaN
# VP_100_1                                 NaN         NaN         NaN
# VpVs_1                                   NaN         NaN         NaN
# VpVs_100_1                               NaN         NaN         NaN
# VS_1_1                                   NaN         NaN         NaN
# VS_1_100_1                               NaN         NaN         NaN
# WELL                              EBONI-14T2  EBONI-14T2  EBONI-14T2
# AVO_VpVs_1_1                             NaN         NaN         NaN
# CALI_COMP_1                              NaN         NaN         NaN
# DTP_COMP_1                               NaN         NaN         NaN
# ELASTIC_DTC_1                            NaN         NaN         NaN
# NP_COMP_1                                NaN         NaN         NaN
# PEM2010_INPUT_DTC_1                      NaN         NaN         NaN
# RHOB_COMP_1                              NaN         NaN         NaN
# RT_COMP_1                         419.830261  424.275238  428.460388
# PETROLAN_SWE_2                           NaN         NaN         NaN
# PETROLAN_SWT_2                           NaN         NaN         NaN
# CALI_COMP_2                              NaN         NaN         NaN
# NP_COMP_2                                NaN         NaN         NaN
# RHOB_COMP_2                              NaN         NaN         NaN
# RT_COMP_2                                NaN         NaN         NaN
# PEM2010_INPUT_RT_int_1                   NaN         NaN         NaN
# PETROLAN_VCL_2                           NaN         NaN         NaN
#
#                                         6955        6956
# dah                                   5496.5      5497.0
# AVO_Vp_1_1                               NaN         NaN
# AVO_Vp_100_1                             NaN         NaN
# AVO_VpVs_1                               NaN         NaN
# AVO_VpVs_100_1                           NaN         NaN
# DTCV_1                                   NaN         NaN
# DTCV_2                                   NaN         NaN
# ELASTIC_RHOB_1                           NaN         NaN
# HCAL_1                                   NaN         NaN
# HCAL_2                                   NaN         NaN
# PEM2010_INPUT_DTC_ISO_1                  NaN         NaN
# PEM2010_INPUT_NP_1                       NaN         NaN
# PEM2010_INPUT_RHOB_1                     NaN         NaN
# PEM2010_INPUT_RT_1                       NaN         NaN
# PEM2010_INPUT_SWE_1                      NaN         NaN
# PEM2010_INPUT_SWT_1                      NaN         NaN
# PEM2010_INPUT_VCL_1                      NaN         NaN
# petro_LNDTP_1                            NaN         NaN
# PETROLAN_SWE_1                           NaN         NaN
# PETROLAN_SWE_BupperFullofWater_1         NaN         NaN
# PETROLAN_SWT_1                           NaN         NaN
# PETROLAN_VCL_1                           NaN         NaN
# RHOB_1_1                                 NaN         NaN
# RHOZ_1                                   NaN         NaN
# RHOZ_2                                   NaN         NaN
# TNPH_1                                   NaN         NaN
# TNPH_2                                   NaN         NaN
# TNPHCOR_1                                NaN         NaN
# TNPHCOR_2                                NaN         NaN
# VP_1_1                                   NaN         NaN
# VP_100_1                                 NaN         NaN
# VpVs_1                                   NaN         NaN
# VpVs_100_1                               NaN         NaN
# VS_1_1                                   NaN         NaN
# VS_1_100_1                               NaN         NaN
# WELL                              EBONI-14T2  EBONI-14T2
# AVO_VpVs_1_1                             NaN         NaN
# CALI_COMP_1                              NaN         NaN
# DTP_COMP_1                               NaN         NaN
# ELASTIC_DTC_1                            NaN         NaN
# NP_COMP_1                                NaN         NaN
# PEM2010_INPUT_DTC_1                      NaN         NaN
# RHOB_COMP_1                              NaN         NaN
# RT_COMP_1                         435.778015  430.752838
# PETROLAN_SWE_2                           NaN         NaN
# PETROLAN_SWT_2                           NaN         NaN
# CALI_COMP_2                              NaN         NaN
# NP_COMP_2                                NaN         NaN
# RHOB_COMP_2                              NaN         NaN
# RT_COMP_2                                NaN         NaN
# PEM2010_INPUT_RT_int_1                   NaN         NaN
# PETROLAN_VCL_2                           NaN         NaN
#
# [52 rows x 69358 columns]

# %% [markdown]
# #### Names of all the available columns in the df

# %%
hd = list(well_df.columns)

# %% [markdown]
# #### select columns to be used in the example

# %%
sel_hd = ['dah','PEM2010_INPUT_DTC_ISO_1',
 'PEM2010_INPUT_NP_1',
 'PEM2010_INPUT_RHOB_1',
 'PEM2010_INPUT_RT_1',
 'PEM2010_INPUT_SWE_1',
 'PEM2010_INPUT_SWT_1',
 'PEM2010_INPUT_VCL_1'
       ,'WELL'  ]

# %%
df = well_df[sel_hd]

# %%
df.head()
# Out:
#       dah  PEM2010_INPUT_DTC_ISO_1  PEM2010_INPUT_NP_1  PEM2010_INPUT_RHOB_1  \
# 0  1401.5                      NaN                 NaN                   NaN
# 1  1402.0                      NaN                 NaN                   NaN
# 2  1402.5                      NaN                 NaN                   NaN
# 3  1403.0                      NaN                 NaN                   NaN
# 4  1403.5                      NaN                 NaN                   NaN
#
#    PEM2010_INPUT_RT_1  PEM2010_INPUT_SWE_1  PEM2010_INPUT_SWT_1  \
# 0                 NaN                  NaN                  NaN
# 1                 NaN                  NaN                  NaN
# 2                 NaN                  NaN                  NaN
# 3                 NaN                  NaN                  NaN
# 4                 NaN                  NaN                  NaN
#
#    PEM2010_INPUT_VCL_1        WELL
# 0                  NaN  EBONI-01ST
# 1                  NaN  EBONI-01ST
# 2                  NaN  EBONI-01ST
# 3                  NaN  EBONI-01ST
# 4                  NaN  EBONI-01ST

# %%
df.tail()
# Out:
#          dah  PEM2010_INPUT_DTC_ISO_1  PEM2010_INPUT_NP_1  \
# 6952  5495.0                      NaN                 NaN
# 6953  5495.5                      NaN                 NaN
# 6954  5496.0                      NaN                 NaN
# 6955  5496.5                      NaN                 NaN
# 6956  5497.0                      NaN                 NaN
#
#       PEM2010_INPUT_RHOB_1  PEM2010_INPUT_RT_1  PEM2010_INPUT_SWE_1  \
# 6952                   NaN                 NaN                  NaN
# 6953                   NaN                 NaN                  NaN
# 6954                   NaN                 NaN                  NaN
# 6955                   NaN                 NaN                  NaN
# 6956                   NaN                 NaN                  NaN
#
#       PEM2010_INPUT_SWT_1  PEM2010_INPUT_VCL_1        WELL
# 6952                  NaN                  NaN  EBONI-14T2
# 6953                  NaN                  NaN  EBONI-14T2
# 6954                  NaN                  NaN  EBONI-14T2
# 6955                  NaN                  NaN  EBONI-14T2
# 6956                  NaN                  NaN  EBONI-14T2

# %% [markdown]
# ### Exploration Data Analysis

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 69358 entries, 0 to 6956
# Data columns (total 9 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   dah                      69358 non-null  float32
#  1   PEM2010_INPUT_DTC_ISO_1  12193 non-null  float32
#  2   PEM2010_INPUT_NP_1       26686 non-null  float32
#  3   PEM2010_INPUT_RHOB_1     26868 non-null  float32
#  4   PEM2010_INPUT_RT_1       33968 non-null  float32
#  5   PEM2010_INPUT_SWE_1      22958 non-null  float32
#  6   PEM2010_INPUT_SWT_1      22952 non-null  float32
#  7   PEM2010_INPUT_VCL_1      22937 non-null  float32
#  8   WELL                     69358 non-null  object
# dtypes: float32(8), object(1)
# memory usage: 3.2+ MB

# %%
df.describe()
# Out:
#                 dah  PEM2010_INPUT_DTC_ISO_1  PEM2010_INPUT_NP_1  \
# count  69358.000000             12193.000000        26686.000000
# mean    2642.766357               110.505600            0.422577
# std     1176.280273                11.739655            0.139565
# min       24.000000                68.136253            0.075226
# 25%     1929.000000               103.792740            0.354088
# 50%     2734.500000               112.015625            0.441646
# 75%     3415.500000               118.696121            0.506712
# max     5497.000000               140.764755            1.277386
#
#        PEM2010_INPUT_RHOB_1  PEM2010_INPUT_RT_1  PEM2010_INPUT_SWE_1  \
# count          26868.000000        33968.000000         22958.000000
# mean               2.341200          168.772507             0.273025
# std                0.105931          829.372375            21.553541
# min                1.590536            0.139245          -999.219055
# 25%                2.281072            0.998123             0.734355
# 50%                2.360066            1.239078             1.000000
# 75%                2.415128            1.755990             1.000000
# max                2.608223         5000.000000             1.000000
#
#        PEM2010_INPUT_SWT_1  PEM2010_INPUT_VCL_1
# count         22952.000000         22937.000000
# mean              0.182033             0.488407
# std              24.561970             0.216369
# min            -999.249939             0.000000
# 25%               0.929424             0.402924
# 50%               1.000000             0.576686
# 75%               1.000000             0.637518
# max               1.000000             0.999971

# %%
import seaborn as sn

# %%
sn.pairplot(df.dropna().reset_index().drop(columns='dah'),hue='WELL' )

# %% [markdown]
# #### Automatic EDA using ydata-profiling

# %%
from ydata_profiling.profile_report import ProfileReport
from ydata_profiling.compare_reports import compare

# %%
ProfileReport(df)

# %% [markdown]
# #### drop null values

# %%
df_nan = df.dropna()
# Out:
#          dah  PEM2010_INPUT_DTC_ISO_1  PEM2010_INPUT_NP_1  \
# 2777  2790.0               135.489365            0.910164
# 2778  2790.5               134.862427            0.818559
# 2779  2791.0               132.657059            0.583486
# 2780  2791.5               130.459320            0.494804
# 2781  2792.0               130.280014            0.488673
# ...      ...                      ...                 ...
# 2552  3582.0               105.921188            0.415538
# 2553  3582.5               106.101868            0.414284
# 2554  3583.0               107.303116            0.420562
# 2555  3583.5               108.497200            0.416306
# 2556  3584.0               108.145157            0.408197
#
#       PEM2010_INPUT_RHOB_1  PEM2010_INPUT_RT_1  PEM2010_INPUT_SWE_1  \
# 2777              2.247842            0.690436                  1.0
# 2778              2.257459            0.732707                  1.0
# 2779              2.283861            0.765060                  1.0
# 2780              2.306006            0.800066                  1.0
# 2781              2.312045            0.826978                  1.0
# ...                    ...                 ...                  ...
# 2552              2.438645            1.315373                  1.0
# 2553              2.437156            1.261288                  1.0
# 2554              2.443460            1.219321                  1.0
# 2555              2.449511            1.183852                  1.0
# 2556              2.449671            1.184341                  1.0
#
#       PEM2010_INPUT_SWT_1  PEM2010_INPUT_VCL_1
# 2777                  1.0             0.595230
# 2778                  1.0             0.628471
# 2779                  1.0             0.645806
# 2780                  1.0             0.657633
# 2781                  1.0             0.653210
# ...                   ...                  ...
# 2552                  1.0             0.679462
# 2553                  1.0             0.677446
# 2554                  1.0             0.687753
# 2555                  1.0             0.678547
# 2556                  1.0             0.685587
#
# [12021 rows x 8 columns]

# %%
pr1 = ProfileReport(df)

# %%
pr2 = ProfileReport(df_nan)

# %%
pr1.compare(pr2)

# %% [markdown]
# #### Remove outliers using PYOD

# %%
from pyod.models import lof
from pyod.utils.ut

# %%
lf = lof.LOF(contamination=0.01)

# %%
lf.fit(df_nan)
# Out:
# LOF(algorithm='auto', contamination=0.01, leaf_size=30, metric='minkowski',
#   metric_params=None, n_jobs=1, n_neighbors=20, novelty=True, p=2)

# %%
df_nan_an = df_nan.copy()

# %%
df_nan_an['anomaly'] = lf.predict(df_nan)
df_nan_an
# Out:
#          dah  PEM2010_INPUT_DTC_ISO_1  PEM2010_INPUT_NP_1  \
# 2777  2790.0               135.489365            0.910164
# 2778  2790.5               134.862427            0.818559
# 2779  2791.0               132.657059            0.583486
# 2780  2791.5               130.459320            0.494804
# 2781  2792.0               130.280014            0.488673
# ...      ...                      ...                 ...
# 2552  3582.0               105.921188            0.415538
# 2553  3582.5               106.101868            0.414284
# 2554  3583.0               107.303116            0.420562
# 2555  3583.5               108.497200            0.416306
# 2556  3584.0               108.145157            0.408197
#
#       PEM2010_INPUT_RHOB_1  PEM2010_INPUT_RT_1  PEM2010_INPUT_SWE_1  \
# 2777              2.247842            0.690436                  1.0
# 2778              2.257459            0.732707                  1.0
# 2779              2.283861            0.765060                  1.0
# 2780              2.306006            0.800066                  1.0
# 2781              2.312045            0.826978                  1.0
# ...                    ...                 ...                  ...
# 2552              2.438645            1.315373                  1.0
# 2553              2.437156            1.261288                  1.0
# 2554              2.443460            1.219321                  1.0
# 2555              2.449511            1.183852                  1.0
# 2556              2.449671            1.184341                  1.0
#
#       PEM2010_INPUT_SWT_1  PEM2010_INPUT_VCL_1  anomaly    scores
# 2777                  1.0             0.595230        0  1.024116
# 2778                  1.0             0.628471        0  0.972216
# 2779                  1.0             0.645806        0  0.964657
# 2780                  1.0             0.657633        0  0.965581
# 2781                  1.0             0.653210        0  0.989609
# ...                   ...                  ...      ...       ...
# 2552                  1.0             0.679462        0  0.989730
# 2553                  1.0             0.677446        0  1.000781
# 2554                  1.0             0.687753        0  0.984885
# 2555                  1.0             0.678547        0  1.001932
# 2556                  1.0             0.685587        0  1.009572
#
# [12021 rows x 10 columns]

# %%
fo2_1.put_log('Double GR', somelogs['dah']['m'].to_numpy(),\
              somelogs['Gamma Ray']['API'].to_numpy()*2,'API','GR',True]
# Out:
#   Cell In[10], line 2
#     somelogs['Gamma Ray']['API'].to_numpy()*2,'API','GR',True]
#                                                              ^
# SyntaxError: closing parenthesis ']' does not match opening parenthesis '(' on line 1

# %%
df_nan_an["scores"] = lf.decision_scores_
df_nan_an
# Out:
#          dah  PEM2010_INPUT_DTC_ISO_1  PEM2010_INPUT_NP_1  \
# 2777  2790.0               135.489365            0.910164
# 2778  2790.5               134.862427            0.818559
# 2779  2791.0               132.657059            0.583486
# 2780  2791.5               130.459320            0.494804
# 2781  2792.0               130.280014            0.488673
# ...      ...                      ...                 ...
# 2552  3582.0               105.921188            0.415538
# 2553  3582.5               106.101868            0.414284
# 2554  3583.0               107.303116            0.420562
# 2555  3583.5               108.497200            0.416306
# 2556  3584.0               108.145157            0.408197
#
#       PEM2010_INPUT_RHOB_1  PEM2010_INPUT_RT_1  PEM2010_INPUT_SWE_1  \
# 2777              2.247842            0.690436                  1.0
# 2778              2.257459            0.732707                  1.0
# 2779              2.283861            0.765060                  1.0
# 2780              2.306006            0.800066                  1.0
# 2781              2.312045            0.826978                  1.0
# ...                    ...                 ...                  ...
# 2552              2.438645            1.315373                  1.0
# 2553              2.437156            1.261288                  1.0
# 2554              2.443460            1.219321                  1.0
# 2555              2.449511            1.183852                  1.0
# 2556              2.449671            1.184341                  1.0
#
#       PEM2010_INPUT_SWT_1  PEM2010_INPUT_VCL_1  anomaly    scores
# 2777                  1.0             0.595230        0  1.024116
# 2778                  1.0             0.628471        0  0.972216
# 2779                  1.0             0.645806        0  0.964657
# 2780                  1.0             0.657633        0  0.965581
# 2781                  1.0             0.653210        0  0.989609
# ...                   ...                  ...      ...       ...
# 2552                  1.0             0.679462        0  0.989730
# 2553                  1.0             0.677446        0  1.000781
# 2554                  1.0             0.687753        0  0.984885
# 2555                  1.0             0.678547        0  1.001932
# 2556                  1.0             0.685587        0  1.009572
#
# [12021 rows x 10 columns]

# %%
import matplotlib.pyplot as plt

# %%
df_nan_an["anomaly"].value_counts()
# Out:
# anomaly
# 0    11919
# 1      102
# Name: count, dtype: int64

# %%
inlier = df_nan[df_nan_an['anomaly']==0]
outlier = df_nan[df_nan_an['anomaly']==1]

# %%
inlier
# Out:
#          dah  PEM2010_INPUT_DTC_ISO_1  PEM2010_INPUT_NP_1  \
# 2777  2790.0               135.489365            0.910164
# 2778  2790.5               134.862427            0.818559
# 2779  2791.0               132.657059            0.583486
# 2780  2791.5               130.459320            0.494804
# 2781  2792.0               130.280014            0.488673
# ...      ...                      ...                 ...
# 2552  3582.0               105.921188            0.415538
# 2553  3582.5               106.101868            0.414284
# 2554  3583.0               107.303116            0.420562
# 2555  3583.5               108.497200            0.416306
# 2556  3584.0               108.145157            0.408197
#
#       PEM2010_INPUT_RHOB_1  PEM2010_INPUT_RT_1  PEM2010_INPUT_SWE_1  \
# 2777              2.247842            0.690436                  1.0
# 2778              2.257459            0.732707                  1.0
# 2779              2.283861            0.765060                  1.0
# 2780              2.306006            0.800066                  1.0
# 2781              2.312045            0.826978                  1.0
# ...                    ...                 ...                  ...
# 2552              2.438645            1.315373                  1.0
# 2553              2.437156            1.261288                  1.0
# 2554              2.443460            1.219321                  1.0
# 2555              2.449511            1.183852                  1.0
# 2556              2.449671            1.184341                  1.0
#
#       PEM2010_INPUT_SWT_1  PEM2010_INPUT_VCL_1
# 2777                  1.0             0.595230
# 2778                  1.0             0.628471
# 2779                  1.0             0.645806
# 2780                  1.0             0.657633
# 2781                  1.0             0.653210
# ...                   ...                  ...
# 2552                  1.0             0.679462
# 2553                  1.0             0.677446
# 2554                  1.0             0.687753
# 2555                  1.0             0.678547
# 2556                  1.0             0.685587
#
# [11919 rows x 8 columns]

# %%
outlier = outlier[["PEM2010_INPUT_DTC_ISO_1"]].sort_index()

# %%
inlier["PEM2010_INPUT_DTC_ISO_1"].sort_index().plot()
plt.scatter(outlier.index,outlier["PEM2010_INPUT_DTC_ISO_1"],c='red' )

# %%
df_inliers = inlier.copy()

# %% [markdown]
# #### Features and targets "in this examples we use SWE as the targets"

# %%
df_inliers.columns
# Out:
# Index(['dah', 'PEM2010_INPUT_DTC_ISO_1', 'PEM2010_INPUT_NP_1',
#        'PEM2010_INPUT_RHOB_1', 'PEM2010_INPUT_RT_1', 'PEM2010_INPUT_SWE_1',
#        'PEM2010_INPUT_SWT_1', 'PEM2010_INPUT_VCL_1'],
#       dtype='object')

# %%
df_inliers['RT_log'] = df_inliers[['PEM2010_INPUT_RT_1']].apply(np.log)

# %%
df_inliers['RT_log'].sort_index().plot()
# Out:
# <Axes: >

# %% [markdown]
# ### Prepare data for Model Building

# %%
Xdata = df_inliers.drop(columns=["PEM2010_INPUT_SWT_1","PEM2010_INPUT_SWE_1","dah"])
ydata = df_inliers[["PEM2010_INPUT_SWE_1"]]

# %% [markdown]
# #### split to training and test data

# %%
from sklearn.model_selection import train_test_split

xtrain,xtest,ytrain, ytest = train_test_split(Xdata,ydata, test_size=0.25)

# %%
xtrain
# Out:
#          dah  PEM2010_INPUT_DTC_ISO_1  PEM2010_INPUT_NP_1  \
# 5104  3953.5               118.826683            0.498617
# 6635  3341.5               129.269867            0.526240
# 2223  3417.5               123.679977            0.538221
# 3170  2986.5               124.971649            0.555451
# 7193  3622.5               107.649063            0.455322
# ...      ...                      ...                 ...
# 2062  3261.0               114.249748            0.410712
# 2106  3055.0               113.732803            0.475658
# 2163  3083.5               116.592888            0.465131
# 6429  3238.5               105.455826            0.400038
# 3113  2958.0               117.526146            0.459735
#
#       PEM2010_INPUT_RHOB_1  PEM2010_INPUT_RT_1  PEM2010_INPUT_VCL_1
# 5104              2.372689            0.513973             0.532114
# 6635              2.376383            0.824355             0.697137
# 2223              2.350369            1.019032             0.709228
# 3170              2.347173            0.874541             0.681563
# 7193              2.425166            1.024827             0.634615
# ...                    ...                 ...                  ...
# 2062              2.381353            1.074662             0.654847
# 2106              2.345136            1.245504             0.691124
# 2163              2.350773            1.210197             0.616953
# 6429              2.361555            1.724362             0.562796
# 3113              2.324158            1.435005             0.586521
#
# [9015 rows x 6 columns]
